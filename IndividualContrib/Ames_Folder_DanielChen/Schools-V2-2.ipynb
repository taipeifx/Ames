# %%
import pandas as pd
import numpy as np
pd.options.display.max_columns=300 #increase columns shown 
ames = pd.read_csv('./data/ames_schoolsv2_2.csv')

# %%
#ames = ames.drop(['Unnamed: 0'], axis = 1)

ames["LotFrontage"] = ames.groupby("Neighborhood")["LotFrontage"].transform(lambda x: x.fillna(x.median()))
#ames.loc[:, "TotalBsmtSF"] = ames.loc[:, "TotalBsmtSF"].fillna(0)

ames.head()
#probably can't use LotFrontage
# Out:
#    LotFrontage  YearBuilt  LotArea  MoSold  YrSold  SalePrice  TotalBsmtSF  \
# 0        141.0       1960    31770       5    2010     215000       1080.0
# 1         73.0       1954    11027       5    2006     149900       1178.0
# 2         85.0       1956    10533       8    2006     157500       1008.0
# 3         74.0       1956    13008      10    2009     124500        882.0
# 4         73.0       1957    11765       6    2006     169000       1617.0
#
#    1stFlrSF Neighborhood     School
# 0      1656        NAmes  Northwood
# 1      1293        NAmes  Northwood
# 2      1024        NAmes  Northwood
# 3       882        NAmes  Northwood
# 4      1797        NAmes  Northwood

# %%
ames['LotFrontage'].isnull().values
# Out:
# array([False, False, False, ..., False, False, False])

# %%
train = pd.read_csv("./data/train.csv")
#train = train.drop(['Unnamed: 0'], axis = 1)
#print(train.shape)
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %%
test = pd.read_csv("./data/test.csv")
#test = test.drop(['Unnamed: 0'], axis = 1)
print (test.shape)
test.head()
# Out:
# (1459, 80)
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     1Story            5            6       1961
# 1       Norm     1Fam     1Story            6            6       1958
# 2       Norm     1Fam     2Story            5            5       1997
# 3       Norm     1Fam     2Story            6            6       1998
# 4       Norm   TwnhsE     1Story            8            5       1992
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          1961     Gable  CompShg     VinylSd     VinylSd       None
# 1          1958       Hip  CompShg     Wd Sdng     Wd Sdng    BrkFace
# 2          1998     Gable  CompShg     VinylSd     VinylSd       None
# 3          1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 4          1992     Gable  CompShg     HdBoard     HdBoard       None
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0         0.0        TA        TA     CBlock       TA       TA           No
# 1       108.0        TA        TA     CBlock       TA       TA           No
# 2         0.0        TA        TA      PConc       Gd       TA           No
# 3        20.0        TA        TA      PConc       TA       TA           No
# 4         0.0        Gd        TA      PConc       Gd       TA           No
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          Rec       468.0          LwQ       144.0      270.0        882.0
# 1          ALQ       923.0          Unf         0.0      406.0       1329.0
# 2          GLQ       791.0          Unf         0.0      137.0        928.0
# 3          GLQ       602.0          Unf         0.0      324.0        926.0
# 4          ALQ       263.0          Unf         0.0     1017.0       1280.0
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        TA          Y      SBrkr       896         0             0
# 1    GasA        TA          Y      SBrkr      1329         0             0
# 2    GasA        Gd          Y      SBrkr       928       701             0
# 3    GasA        Ex          Y      SBrkr       926       678             0
# 4    GasA        Ex          Y      SBrkr      1280         0             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0        896           0.0           0.0         1         0             2
# 1       1329           0.0           0.0         1         1             3
# 2       1629           0.0           0.0         2         1             3
# 3       1604           0.0           0.0         2         1             3
# 4       1280           0.0           0.0         2         0             2
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          TA             5        Typ           0         NaN
# 1             1          Gd             6        Typ           0         NaN
# 2             1          TA             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             5        Typ           0         NaN
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       1961.0          Unf         1.0       730.0         TA
# 1     Attchd       1958.0          Unf         1.0       312.0         TA
# 2     Attchd       1997.0          Fin         2.0       482.0         TA
# 3     Attchd       1998.0          Fin         2.0       470.0         TA
# 4     Attchd       1992.0          RFn         2.0       506.0         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y         140            0              0          0
# 1         TA          Y         393           36              0          0
# 2         TA          Y         212           34              0          0
# 3         TA          Y         360           36              0          0
# 4         TA          Y           0           82              0          0
#
#    ScreenPorch  PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0          120         0    NaN  MnPrv         NaN        0       6    2010
# 1            0         0    NaN    NaN        Gar2    12500       6    2010
# 2            0         0    NaN  MnPrv         NaN        0       3    2010
# 3            0         0    NaN    NaN         NaN        0       6    2010
# 4          144         0    NaN    NaN         NaN        0       1    2010
#
#   SaleType SaleCondition
# 0       WD        Normal
# 1       WD        Normal
# 2       WD        Normal
# 3       WD        Normal
# 4       WD        Normal

# %%
test_price = pd.read_csv("./data/answerkey.csv")
test_price = test_price.drop(['Unnamed: 0'], axis = 1)
test_price.head()
# Out:
#      Id  SalePrice
# 0  1461     105000
# 1  1462     172000
# 2  1463     189900
# 3  1464     195500
# 4  1465     191500

# %%
test['SalePrice'] = test_price['SalePrice']
# Add SalePrice = 99 to test set
test['SalePrice2'] = 99

print(test.shape)
test.head()
# Out:
# (1459, 82)
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     1Story            5            6       1961
# 1       Norm     1Fam     1Story            6            6       1958
# 2       Norm     1Fam     2Story            5            5       1997
# 3       Norm     1Fam     2Story            6            6       1998
# 4       Norm   TwnhsE     1Story            8            5       1992
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          1961     Gable  CompShg     VinylSd     VinylSd       None
# 1          1958       Hip  CompShg     Wd Sdng     Wd Sdng    BrkFace
# 2          1998     Gable  CompShg     VinylSd     VinylSd       None
# 3          1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 4          1992     Gable  CompShg     HdBoard     HdBoard       None
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0         0.0        TA        TA     CBlock       TA       TA           No
# 1       108.0        TA        TA     CBlock       TA       TA           No
# 2         0.0        TA        TA      PConc       Gd       TA           No
# 3        20.0        TA        TA      PConc       TA       TA           No
# 4         0.0        Gd        TA      PConc       Gd       TA           No
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          Rec       468.0          LwQ       144.0      270.0        882.0
# 1          ALQ       923.0          Unf         0.0      406.0       1329.0
# 2          GLQ       791.0          Unf         0.0      137.0        928.0
# 3          GLQ       602.0          Unf         0.0      324.0        926.0
# 4          ALQ       263.0          Unf         0.0     1017.0       1280.0
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        TA          Y      SBrkr       896         0             0
# 1    GasA        TA          Y      SBrkr      1329         0             0
# 2    GasA        Gd          Y      SBrkr       928       701             0
# 3    GasA        Ex          Y      SBrkr       926       678             0
# 4    GasA        Ex          Y      SBrkr      1280         0             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0        896           0.0           0.0         1         0             2
# 1       1329           0.0           0.0         1         1             3
# 2       1629           0.0           0.0         2         1             3
# 3       1604           0.0           0.0         2         1             3
# 4       1280           0.0           0.0         2         0             2
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          TA             5        Typ           0         NaN
# 1             1          Gd             6        Typ           0         NaN
# 2             1          TA             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             5        Typ           0         NaN
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       1961.0          Unf         1.0       730.0         TA
# 1     Attchd       1958.0          Unf         1.0       312.0         TA
# 2     Attchd       1997.0          Fin         2.0       482.0         TA
# 3     Attchd       1998.0          Fin         2.0       470.0         TA
# 4     Attchd       1992.0          RFn         2.0       506.0         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y         140            0              0          0
# 1         TA          Y         393           36              0          0
# 2         TA          Y         212           34              0          0
# 3         TA          Y         360           36              0          0
# 4         TA          Y           0           82              0          0
#
#    ScreenPorch  PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0          120         0    NaN  MnPrv         NaN        0       6    2010
# 1            0         0    NaN    NaN        Gar2    12500       6    2010
# 2            0         0    NaN  MnPrv         NaN        0       3    2010
# 3            0         0    NaN    NaN         NaN        0       6    2010
# 4          144         0    NaN    NaN         NaN        0       1    2010
#
#   SaleType SaleCondition  SalePrice  SalePrice2
# 0       WD        Normal     105000          99
# 1       WD        Normal     172000          99
# 2       WD        Normal     189900          99
# 3       WD        Normal     195500          99
# 4       WD        Normal     191500          99

# %%
# Get a combined dataset
dataset = test.append(train)
dataset.shape
# Out:
# (2919, 82)

# %%
dataset["LotFrontage"] = dataset.groupby("Neighborhood")["LotFrontage"].transform(lambda x: x.fillna(x.median()))
print(dataset['LotFrontage'].isna().sum())
# Out:
# 0

# %%
print (ames.shape)
# Out:
# (2930, 10)

# %%
# the count from R:
# Edwards   Fellows      High    Meeker    Middle  Mitchell Northwood    Sawyer 
# 284       368       784       511       301       163       181       338 
#merged table in python should have the same values

# %%
ames.columns
# Out:
# Index(['LotFrontage', 'YearBuilt', 'LotArea', 'MoSold', 'YrSold', 'SalePrice',
#        'TotalBsmtSF', '1stFlrSF', 'Neighborhood', 'School'],
#       dtype='object')

# %%
schools = pd.merge(dataset, ames, on=['LotFrontage','LotArea','YearBuilt','TotalBsmtSF','MoSold', 'YrSold', 'SalePrice','1stFlrSF','Neighborhood'], how='left') 
schools.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch Alley  BedroomAbvGr BldgType BsmtCond  \
# 0       896         0          0   NaN             2     1Fam       TA
# 1      1329         0          0   NaN             3     1Fam       TA
# 2       928       701          0   NaN             3     1Fam       TA
# 3       926       678          0   NaN             3     1Fam       TA
# 4      1280         0          0   NaN             2   TwnhsE       TA
#
#   BsmtExposure  BsmtFinSF1  BsmtFinSF2 BsmtFinType1 BsmtFinType2  \
# 0           No       468.0       144.0          Rec          LwQ
# 1           No       923.0         0.0          ALQ          Unf
# 2           No       791.0         0.0          GLQ          Unf
# 3           No       602.0         0.0          GLQ          Unf
# 4           No       263.0         0.0          ALQ          Unf
#
#    BsmtFullBath  BsmtHalfBath BsmtQual  BsmtUnfSF CentralAir Condition1  \
# 0           0.0           0.0       TA      270.0          Y      Feedr
# 1           0.0           0.0       TA      406.0          Y       Norm
# 2           0.0           0.0       Gd      137.0          Y       Norm
# 3           0.0           0.0       TA      324.0          Y       Norm
# 4           0.0           0.0       Gd     1017.0          Y       Norm
#
#   Condition2 Electrical  EnclosedPorch ExterCond ExterQual Exterior1st  \
# 0       Norm      SBrkr              0        TA        TA     VinylSd
# 1       Norm      SBrkr              0        TA        TA     Wd Sdng
# 2       Norm      SBrkr              0        TA        TA     VinylSd
# 3       Norm      SBrkr              0        TA        TA     VinylSd
# 4       Norm      SBrkr              0        TA        Gd     HdBoard
#
#   Exterior2nd  Fence FireplaceQu  Fireplaces Foundation  FullBath Functional  \
# 0     VinylSd  MnPrv         NaN           0     CBlock         1        Typ
# 1     Wd Sdng    NaN         NaN           0     CBlock         1        Typ
# 2     VinylSd  MnPrv          TA           1      PConc         2        Typ
# 3     VinylSd    NaN          Gd           1      PConc         2        Typ
# 4     HdBoard    NaN         NaN           0      PConc         2        Typ
#
#    GarageArea  GarageCars GarageCond GarageFinish GarageQual GarageType  \
# 0       730.0         1.0         TA          Unf         TA     Attchd
# 1       312.0         1.0         TA          Unf         TA     Attchd
# 2       482.0         2.0         TA          Fin         TA     Attchd
# 3       470.0         2.0         TA          Fin         TA     Attchd
# 4       506.0         2.0         TA          RFn         TA     Attchd
#
#    GarageYrBlt  GrLivArea  HalfBath Heating HeatingQC HouseStyle    Id  \
# 0       1961.0        896         0    GasA        TA     1Story  1461
# 1       1958.0       1329         1    GasA        TA     1Story  1462
# 2       1997.0       1629         1    GasA        Gd     2Story  1463
# 3       1998.0       1604         1    GasA        Ex     2Story  1464
# 4       1992.0       1280         0    GasA        Ex     1Story  1465
#
#    KitchenAbvGr KitchenQual LandContour LandSlope  LotArea LotConfig  \
# 0             1          TA         Lvl       Gtl    11622    Inside
# 1             1          Gd         Lvl       Gtl    14267    Corner
# 2             1          TA         Lvl       Gtl    13830    Inside
# 3             1          Gd         Lvl       Gtl     9978    Inside
# 4             1          Gd         HLS       Gtl     5005    Inside
#
#    LotFrontage LotShape  LowQualFinSF  MSSubClass MSZoning  MasVnrArea  \
# 0         80.0      Reg             0          20       RH         0.0
# 1         81.0      IR1             0          20       RL       108.0
# 2         74.0      IR1             0          60       RL         0.0
# 3         78.0      IR1             0          60       RL        20.0
# 4         43.0      IR1             0         120       RL         0.0
#
#   MasVnrType MiscFeature  MiscVal  MoSold Neighborhood  OpenPorchSF  \
# 0       None         NaN        0       6        NAmes            0
# 1    BrkFace        Gar2    12500       6        NAmes           36
# 2       None         NaN        0       3      Gilbert           34
# 3    BrkFace         NaN        0       6      Gilbert           36
# 4       None         NaN        0       1      StoneBr           82
#
#    OverallCond  OverallQual PavedDrive  PoolArea PoolQC RoofMatl RoofStyle  \
# 0            6            5          Y         0    NaN  CompShg     Gable
# 1            6            6          Y         0    NaN  CompShg       Hip
# 2            5            5          Y         0    NaN  CompShg     Gable
# 3            6            6          Y         0    NaN  CompShg     Gable
# 4            5            8          Y         0    NaN  CompShg     Gable
#
#   SaleCondition  SalePrice  SalePrice2 SaleType  ScreenPorch Street  \
# 0        Normal     105000        99.0       WD          120   Pave
# 1        Normal     172000        99.0       WD            0   Pave
# 2        Normal     189900        99.0       WD            0   Pave
# 3        Normal     195500        99.0       WD            0   Pave
# 4        Normal     191500        99.0       WD          144   Pave
#
#    TotRmsAbvGrd  TotalBsmtSF Utilities  WoodDeckSF  YearBuilt  YearRemodAdd  \
# 0             5        882.0    AllPub         140       1961          1961
# 1             6       1329.0    AllPub         393       1958          1958
# 2             6        928.0    AllPub         212       1997          1998
# 3             7        926.0    AllPub         360       1998          1998
# 4             5       1280.0    AllPub           0       1992          1992
#
#    YrSold     School
# 0    2010  Northwood
# 1    2010  Northwood
# 2    2010       High
# 3    2010       High
# 4    2010  Northwood

# %%
#schools.groupby('School')['School'].count()

# %%
schools.shape
# Out:
# (2922, 83)

# %%
#schools['School'].isnull().values.any()
print(schools['School'].isna().sum())
# Out:
# 11

# %%
schools.shape
# Out:
# (2922, 83)

# %%
#Check duplicates
a = schools['Id']

import collections
print ([item for item, count in collections.Counter(a).items() if count > 1])

# [1840, 739, 895]
# Out:
# [1840, 739, 895]

# %%
schools[schools['Id'] == 1840]
# Out:
#      1stFlrSF  2ndFlrSF  3SsnPorch  Alley_None  Alley_Pave  BedroomAbvGr  \
# 379      1200         0          0           1           0             3
# 380      1200         0          0           1           0             3
#
#      BldgType_2fmCon  BldgType_Duplex  BldgType_Twnhs  BldgType_TwnhsE  \
# 379                0                1               0                0
# 380                0                1               0                0
#
#      BsmtCond_Gd  BsmtCond_No  BsmtCond_Po  BsmtCond_TA  BsmtExposure_Gd  \
# 379            1            0            0            0                1
# 380            1            0            0            0                1
#
#      BsmtExposure_Mn  BsmtExposure_No  BsmtFinSF1  BsmtFinSF2  \
# 379                0                0      1200.0         0.0
# 380                0                0      1200.0         0.0
#
#      BsmtFinType1_BLQ  BsmtFinType1_GLQ  BsmtFinType1_LwQ  BsmtFinType1_No  \
# 379                 0                 1                 0                0
# 380                 0                 1                 0                0
#
#      BsmtFinType1_Rec  BsmtFinType1_Unf  BsmtFinType2_BLQ  BsmtFinType2_GLQ  \
# 379                 0                 0                 0                 0
# 380                 0                 0                 0                 0
#
#      BsmtFinType2_LwQ  BsmtFinType2_No  BsmtFinType2_Rec  BsmtFinType2_Unf  \
# 379                 0                0                 0                 1
# 380                 0                0                 0                 1
#
#      BsmtFullBath  BsmtHalfBath  BsmtQual_Fa  BsmtQual_Gd  BsmtQual_No  \
# 379           3.0           0.0            0            1            0
# 380           3.0           0.0            0            1            0
#
#      BsmtQual_TA  BsmtUnfSF  CentralAir_Y  Condition1_Feedr  Condition1_Norm  \
# 379            0        0.0             1                 0                1
# 380            0        0.0             1                 0                1
#
#      Condition1_PosA  Condition1_PosN  Condition1_RRAe  Condition1_RRAn  \
# 379                0                0                0                0
# 380                0                0                0                0
#
#      Condition1_RRNe  Condition1_RRNn  Condition2_Feedr  Condition2_Norm  \
# 379                0                0                 0                1
# 380                0                0                 0                1
#
#      Condition2_PosA  Condition2_PosN  Condition2_RRAe  Condition2_RRAn  \
# 379                0                0                0                0
# 380                0                0                0                0
#
#      Condition2_RRNn      Corn  DJREI  Electrical_FuseF  Electrical_FuseP  \
# 379                0  4.950426  99.77                 0                 0
# 380                0  4.950426  99.77                 0                 0
#
#      Electrical_Mix  Electrical_SBrkr  EnclosedPorch  ExterCond_Fa  \
# 379               0                 1              0             0
# 380               0                 1              0             0
#
#      ExterCond_Gd  ExterCond_Po  ExterCond_TA  ExterQual_Fa  ExterQual_Gd  \
# 379             1             0             0             0             0
# 380             1             0             0             0             0
#
#      ExterQual_TA  Exterior1st_AsphShn  Exterior1st_BrkComm  \
# 379             1                    0                    0
# 380             1                    0                    0
#
#      Exterior1st_BrkFace  Exterior1st_CBlock  Exterior1st_CemntBd  \
# 379                    0                   0                    0
# 380                    0                   0                    0
#
#      Exterior1st_HdBoard  Exterior1st_ImStucc  Exterior1st_MetalSd  \
# 379                    0                    0                    0
# 380                    0                    0                    0
#
#      Exterior1st_Plywood  Exterior1st_Stone  Exterior1st_Stucco  \
# 379                    1                  0                   0
# 380                    1                  0                   0
#
#      Exterior1st_VinylSd  Exterior1st_Wd Sdng  Exterior1st_WdShing  \
# 379                    0                    0                    0
# 380                    0                    0                    0
#
#      Exterior2nd_AsphShn  Exterior2nd_Brk Cmn  Exterior2nd_BrkFace  \
# 379                    0                    0                    0
# 380                    0                    0                    0
#
#      Exterior2nd_CBlock  Exterior2nd_CmentBd  Exterior2nd_HdBoard  \
# 379                   0                    0                    0
# 380                   0                    0                    0
#
#      Exterior2nd_ImStucc  Exterior2nd_MetalSd  Exterior2nd_Other  \
# 379                    0                    0                  0
# 380                    0                    0                  0
#
#      Exterior2nd_Plywood  Exterior2nd_Stone  Exterior2nd_Stucco  \
# 379                    1                  0                   0
# 380                    1                  0                   0
#
#      Exterior2nd_VinylSd  Exterior2nd_Wd Sdng  Exterior2nd_Wd Shng  Fannie  \
# 379                    0                    0                    0   4.918
# 380                    0                    0                    0   4.918
#
#      Fence_GdWo  Fence_MnPrv  Fence_MnWw  Fence_No  FireplaceQu_Fa  \
# 379           0            0           0         1               0
# 380           0            0           0         1               0
#
#      FireplaceQu_Gd  FireplaceQu_No  FireplaceQu_Po  FireplaceQu_TA  \
# 379               0               1               0               0
# 380               0               1               0               0
#
#      Fireplaces  Foundation_CBlock  Foundation_PConc  Foundation_Slab  \
# 379           0                  1                 0                0
# 380           0                  1                 0                0
#
#      Foundation_Stone  Foundation_Wood  FullBath  Functional_Maj2  \
# 379                 0                0         3                0
# 380                 0                0         3                0
#
#      Functional_Min1  Functional_Min2  Functional_Mod  Functional_Sev  \
# 379                0                0               0               0
# 380                0                0               0               0
#
#      Functional_Typ  GarageArea  GarageCars  GarageCond_Fa  GarageCond_Gd  \
# 379               1         0.0         0.0              0              0
# 380               1         0.0         0.0              0              0
#
#      GarageCond_No  GarageCond_Po  GarageCond_TA  GarageFinish_No  \
# 379              1              0              0                1
# 380              1              0              0                1
#
#      GarageFinish_RFn  GarageFinish_Unf  GarageQual_Fa  GarageQual_Gd  \
# 379                 0                 0              0              0
# 380                 0                 0              0              0
#
#      GarageQual_No  GarageQual_Po  GarageQual_TA  GarageType_Attchd  \
# 379              1              0              0                  0
# 380              1              0              0                  0
#
#      GarageType_Basment  GarageType_BuiltIn  GarageType_CarPort  \
# 379                   0                   0                   0
# 380                   0                   0                   0
#
#      GarageType_Detchd  GarageType_No  GarageYrBlt  GrLivArea  HalfBath  \
# 379                  0              1          0.0       1200         0
# 380                  0              1          0.0       1200         0
#
#      HeatingQC_Fa  HeatingQC_Gd  HeatingQC_Po  HeatingQC_TA  Heating_GasA  \
# 379             0             0             0             1             1
# 380             0             0             0             1             1
#
#      Heating_GasW  Heating_Grav  Heating_OthW  Heating_Wall  \
# 379             0             0             0             0
# 380             0             0             0             0
#
#      HouseStyle_1.5Unf  HouseStyle_1Story  HouseStyle_2.5Fin  \
# 379                  0                  1                  0
# 380                  0                  1                  0
#
#      HouseStyle_2.5Unf  HouseStyle_2Story  HouseStyle_SFoyer  HouseStyle_SLvl  \
# 379                  0                  0                  0                0
# 380                  0                  0                  0                0
#
#        Id  KitchenAbvGr  KitchenQual_Fa  KitchenQual_Gd  KitchenQual_TA  \
# 379  1840             1               0               0               1
# 380  1840             1               0               0               1
#
#      LaborForce  LandContour_HLS  LandContour_Low  LandContour_Lvl  \
# 379     49552.0                0                0                1
# 380     49552.0                0                0                1
#
#      LandSlope_Mod  LandSlope_Sev  LotArea  LotConfig_CulDSac  LotConfig_FR2  \
# 379              0              0    10800                  0              0
# 380              0              0    10800                  0              0
#
#      LotConfig_FR3  LotConfig_Inside  LotFrontage  LotShape_IR2  LotShape_IR3  \
# 379              0                 1         60.0             0             0
# 380              0                 1         60.0             0             0
#
#      LotShape_Reg  LowQualFinSF  MSSubClass_120  MSSubClass_150  \
# 379             1             0               0               0
# 380             1             0               0               0
#
#      MSSubClass_160  MSSubClass_180  MSSubClass_190  MSSubClass_30  \
# 379               0               0               0              0
# 380               0               0               0              0
#
#      MSSubClass_40  MSSubClass_45  MSSubClass_50  MSSubClass_60  \
# 379              0              0              0              0
# 380              0              0              0              0
#
#      MSSubClass_70  MSSubClass_75  MSSubClass_80  MSSubClass_85  \
# 379              0              0              0              0
# 380              0              0              0              0
#
#      MSSubClass_90  MSZoning_FV  MSZoning_RH  MSZoning_RL  MSZoning_RM  \
# 379              1            0            0            1            0
# 380              1            0            0            1            0
#
#      MasVnrArea  MasVnrType_BrkFace  MasVnrType_None  MasVnrType_Stone  \
# 379         0.0                   0                1                 0
# 380         0.0                   0                1                 0
#
#      MiscFeature_No  MiscFeature_Othr  MiscFeature_Shed  MiscFeature_TenC  \
# 379               1                 0                 0                 0
# 380               1                 0                 0                 0
#
#      MiscVal  MoSold   Month  Neighborhood_Blueste  Neighborhood_BrDale  \
# 379        0       3  200903                     0                    0
# 380        0       3  200903                     0                    0
#
#      Neighborhood_BrkSide  Neighborhood_ClearCr  Neighborhood_CollgCr  \
# 379                     0                     0                     0
# 380                     0                     0                     0
#
#      Neighborhood_Crawfor  Neighborhood_Edwards  Neighborhood_Gilbert  \
# 379                     0                     1                     0
# 380                     0                     1                     0
#
#      Neighborhood_IDOTRR  Neighborhood_MeadowV  Neighborhood_Mitchel  \
# 379                    0                     0                     0
# 380                    0                     0                     0
#
#      Neighborhood_NAmes  Neighborhood_NPkVill  Neighborhood_NWAmes  \
# 379                   0                     0                    0
# 380                   0                     0                    0
#
#      Neighborhood_NoRidge  Neighborhood_NridgHt  Neighborhood_OldTown  \
# 379                     0                     0                     0
# 380                     0                     0                     0
#
#      Neighborhood_SWISU  Neighborhood_Sawyer  Neighborhood_SawyerW  \
# 379                   0                    0                     0
# 380                   0                    0                     0
#
#      Neighborhood_Somerst  Neighborhood_StoneBr  Neighborhood_Timber  \
# 379                     0                     0                    0
# 380                     0                     0                    0
#
#      Neighborhood_Veenker  OpenPorchSF  OverallCond  OverallQual  \
# 379                     0            0            5            5
# 380                     0            0            5            5
#
#      PavedDrive_P  PavedDrive_Y  PoolArea  PoolQC_Fa  PoolQC_Gd  PoolQC_No  \
# 379             0             1         0          0          0          1
# 380             0             1         0          0          0          1
#
#      RoofMatl_CompShg  RoofMatl_Membran  RoofMatl_Metal  RoofMatl_Roll  \
# 379                 1                 0               0              0
# 380                 1                 0               0              0
#
#      RoofMatl_Tar&Grv  RoofMatl_WdShake  RoofMatl_WdShngl  RoofStyle_Gable  \
# 379                 0                 0                 0                1
# 380                 0                 0                 0                1
#
#      RoofStyle_Gambrel  RoofStyle_Hip  RoofStyle_Mansard  RoofStyle_Shed  \
# 379                  0              0                  0               0
# 380                  0              0                  0               0
#
#      SaleCondition_AdjLand  SaleCondition_Alloca  SaleCondition_Family  \
# 379                      0                     1                     0
# 380                      0                     1                     0
#
#      SaleCondition_Normal  SaleCondition_Partial  SalePrice  SalePrice2  \
# 379                     0                      0     179000        99.0
# 380                     0                      0     179000        99.0
#
#      SaleType_CWD  SaleType_Con  SaleType_ConLD  SaleType_ConLI  \
# 379             0             0               0               0
# 380             0             0               0               0
#
#      SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  ScreenPorch  \
# 379               0             0             0            1            0
# 380               0             0             0            1            0
#
#      Street_Pave  TotRmsAbvGrd  TotalBsmtSF  UnemplRate  Utilities_NoSeWa  \
# 379            1             5       1200.0         4.8                 0
# 380            1             5       1200.0         4.8                 0
#
#      WoodDeckSF  YearBuilt  YearRemodAdd  YrSold Neighborhood  EdwardsSchool  \
# 379         120       1987          1988    2009      Edwards       2.654021
# 380         120       1987          1988    2009      Edwards       2.656235
#
#      FellowsSchool  MeekerSchool  MitchellSchool  SawyerSchool  \
# 379       2.983976      3.918035        6.327546      1.689466
# 380       2.981803      3.915541        6.325217      1.692196
#
#      NorthwoodSchool  MiddleSchool  HighSchool
# 379         4.100079      1.958558    2.300503
# 380         4.098028      1.959845    2.298401

# %%
schools = schools.drop_duplicates(subset=['Id'], keep= 'first', inplace=False)
schools.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch Alley  BedroomAbvGr BldgType BsmtCond  \
# 0       896         0          0   NaN             2     1Fam       TA
# 1      1329         0          0   NaN             3     1Fam       TA
# 2       928       701          0   NaN             3     1Fam       TA
# 3       926       678          0   NaN             3     1Fam       TA
# 4      1280         0          0   NaN             2   TwnhsE       TA
#
#   BsmtExposure  BsmtFinSF1  BsmtFinSF2 BsmtFinType1 BsmtFinType2  \
# 0           No       468.0       144.0          Rec          LwQ
# 1           No       923.0         0.0          ALQ          Unf
# 2           No       791.0         0.0          GLQ          Unf
# 3           No       602.0         0.0          GLQ          Unf
# 4           No       263.0         0.0          ALQ          Unf
#
#    BsmtFullBath  BsmtHalfBath BsmtQual  BsmtUnfSF CentralAir Condition1  \
# 0           0.0           0.0       TA      270.0          Y      Feedr
# 1           0.0           0.0       TA      406.0          Y       Norm
# 2           0.0           0.0       Gd      137.0          Y       Norm
# 3           0.0           0.0       TA      324.0          Y       Norm
# 4           0.0           0.0       Gd     1017.0          Y       Norm
#
#   Condition2 Electrical  EnclosedPorch ExterCond ExterQual Exterior1st  \
# 0       Norm      SBrkr              0        TA        TA     VinylSd
# 1       Norm      SBrkr              0        TA        TA     Wd Sdng
# 2       Norm      SBrkr              0        TA        TA     VinylSd
# 3       Norm      SBrkr              0        TA        TA     VinylSd
# 4       Norm      SBrkr              0        TA        Gd     HdBoard
#
#   Exterior2nd  Fence FireplaceQu  Fireplaces Foundation  FullBath Functional  \
# 0     VinylSd  MnPrv         NaN           0     CBlock         1        Typ
# 1     Wd Sdng    NaN         NaN           0     CBlock         1        Typ
# 2     VinylSd  MnPrv          TA           1      PConc         2        Typ
# 3     VinylSd    NaN          Gd           1      PConc         2        Typ
# 4     HdBoard    NaN         NaN           0      PConc         2        Typ
#
#    GarageArea  GarageCars GarageCond GarageFinish GarageQual GarageType  \
# 0       730.0         1.0         TA          Unf         TA     Attchd
# 1       312.0         1.0         TA          Unf         TA     Attchd
# 2       482.0         2.0         TA          Fin         TA     Attchd
# 3       470.0         2.0         TA          Fin         TA     Attchd
# 4       506.0         2.0         TA          RFn         TA     Attchd
#
#    GarageYrBlt  GrLivArea  HalfBath Heating HeatingQC HouseStyle    Id  \
# 0       1961.0        896         0    GasA        TA     1Story  1461
# 1       1958.0       1329         1    GasA        TA     1Story  1462
# 2       1997.0       1629         1    GasA        Gd     2Story  1463
# 3       1998.0       1604         1    GasA        Ex     2Story  1464
# 4       1992.0       1280         0    GasA        Ex     1Story  1465
#
#    KitchenAbvGr KitchenQual LandContour LandSlope  LotArea LotConfig  \
# 0             1          TA         Lvl       Gtl    11622    Inside
# 1             1          Gd         Lvl       Gtl    14267    Corner
# 2             1          TA         Lvl       Gtl    13830    Inside
# 3             1          Gd         Lvl       Gtl     9978    Inside
# 4             1          Gd         HLS       Gtl     5005    Inside
#
#    LotFrontage LotShape  LowQualFinSF  MSSubClass MSZoning  MasVnrArea  \
# 0         80.0      Reg             0          20       RH         0.0
# 1         81.0      IR1             0          20       RL       108.0
# 2         74.0      IR1             0          60       RL         0.0
# 3         78.0      IR1             0          60       RL        20.0
# 4         43.0      IR1             0         120       RL         0.0
#
#   MasVnrType MiscFeature  MiscVal  MoSold Neighborhood  OpenPorchSF  \
# 0       None         NaN        0       6        NAmes            0
# 1    BrkFace        Gar2    12500       6        NAmes           36
# 2       None         NaN        0       3      Gilbert           34
# 3    BrkFace         NaN        0       6      Gilbert           36
# 4       None         NaN        0       1      StoneBr           82
#
#    OverallCond  OverallQual PavedDrive  PoolArea PoolQC RoofMatl RoofStyle  \
# 0            6            5          Y         0    NaN  CompShg     Gable
# 1            6            6          Y         0    NaN  CompShg       Hip
# 2            5            5          Y         0    NaN  CompShg     Gable
# 3            6            6          Y         0    NaN  CompShg     Gable
# 4            5            8          Y         0    NaN  CompShg     Gable
#
#   SaleCondition  SalePrice  SalePrice2 SaleType  ScreenPorch Street  \
# 0        Normal     105000        99.0       WD          120   Pave
# 1        Normal     172000        99.0       WD            0   Pave
# 2        Normal     189900        99.0       WD            0   Pave
# 3        Normal     195500        99.0       WD            0   Pave
# 4        Normal     191500        99.0       WD          144   Pave
#
#    TotRmsAbvGrd  TotalBsmtSF Utilities  WoodDeckSF  YearBuilt  YearRemodAdd  \
# 0             5        882.0    AllPub         140       1961          1961
# 1             6       1329.0    AllPub         393       1958          1958
# 2             6        928.0    AllPub         212       1997          1998
# 3             7        926.0    AllPub         360       1998          1998
# 4             5       1280.0    AllPub           0       1992          1992
#
#    YrSold     School
# 0    2010  Northwood
# 1    2010  Northwood
# 2    2010       High
# 3    2010       High
# 4    2010  Northwood

# %%
a = schools['Id']
print ([item for item, count in collections.Counter(a).items() if count > 1])

print (schools.shape)
# Out:
# []
# (2919, 83)

# %%
schools['School'].isna().sum()
# Out:
# 11

# %%
schools = schools.reset_index(drop=True)
schools = schools[['Id','SalePrice','SalePrice2', 'School']]

# %%
schools.head(20)
# Out:
#       Id  SalePrice  SalePrice2     School
# 0   1461     105000        99.0  Northwood
# 1   1462     172000        99.0  Northwood
# 2   1463     189900        99.0       High
# 3   1464     195500        99.0       High
# 4   1465     191500        99.0  Northwood
# 5   1466     175900        99.0    Fellows
# 6   1467     185000        99.0    Fellows
# 7   1468     180400        99.0       High
# 8   1469     171500        99.0    Fellows
# 9   1470     126000        99.0  Northwood
# 10  1471     184000        99.0  Northwood
# 11  1472      96000        99.0  Northwood
# 12  1473     105500        99.0    Fellows
# 13  1474     149900        99.0  Northwood
# 14  1475     120000        99.0  Northwood
# 15  1476     376162        99.0       High
# 16  1477     290941        99.0       High
# 17  1478     275000        99.0       High
# 18  1479     259000        99.0       High
# 19  1480     500000        99.0       High

# %%
schools.to_csv('./data/schoolsV2_2.csv')
